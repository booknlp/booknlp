# %%
import json
from collections import Counter

# %%
def proc(filename):
    with open(filename) as file:
        data=json.load(file)
    return data

# %%
data=proc("158_emma/158_emma.book")

# %%
def get_counter_from_dependency_list(dep_list):
    counter=Counter()
    for token in dep_list:
        term=token["w"]
        tokenGlobalIndex=token["i"]
        counter[term]+=1
    return counter

# %%
for character in data["characters"]:
    possCounter=Counter()
    
    agentList=character["agent"]
    patientList=character["patient"]
    possList=character["poss"]
    modList=character["mod"]
    
    character_id=character["id"]
    count=character["count"]

    referential_gender_distribution=referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""
    
    # print out the characters with proper names, along with their syntactic information
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]
    
        print(character_id, count, max_proper_mention, referential_gender)

        print()
        printTop=10
        for k, v in get_counter_from_dependency_list(possList).most_common(printTop):
            print("\tposs\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(agentList).most_common(printTop):
            print("\tagent\t%s %s" % (v,k))        
        print()
        for k, v in get_counter_from_dependency_list(patientList).most_common(printTop):
            print("\tpatient\t%s %s" % (v,k))       
        print()
        for k, v in get_counter_from_dependency_list(modList).most_common(printTop):
            print("\tmod\t%s %s" % (v,k))    
        print()
# Out:
# 123 4405 Emma she/her
#
# 	poss	78 father
# 	poss	43 friend
# 	poss	21 mind
# 	poss	16 heart
# 	poss	15 opinion
# 	poss	12 eyes
# 	poss	12 feelings
# 	poss	11 attention
# 	poss	11 dear
# 	poss	10 sister
#
# 	agent	113 said
# 	agent	98 had
# 	agent	59 have
# 	agent	55 thought
# 	agent	55 think
# 	agent	53 know
# 	agent	44 felt
# 	agent	40 saw
# 	agent	39 found
# 	agent	31 say
#
# 	patient	18 told
# 	patient	14 obliged
# 	patient	11 tell
# 	patient	11 assure
# 	patient	9 struck
# 	patient	7 convinced
# 	patient	6 left
# 	patient	6 see
# 	patient	6 cried
# 	patient	5 led
#
# 	mod	44 sure
# 	mod	13 sorry
# 	mod	11 afraid
# 	mod	10 happy
# 	mod	10 glad
# 	mod	8 ashamed
# 	mod	6 delighted
# 	mod	6 pleased
# 	mod	6 ready
# 	mod	5 satisfied
#
# 111 1832 Harriet she/her
#
# 	poss	15 mind
# 	poss	12 father
# 	poss	11 friend
# 	poss	7 manner
# 	poss	7 feelings
# 	poss	5 beauty
# 	poss	5 acquaintance
# 	poss	5 side
# 	poss	5 account
# 	poss	5 affection
#
# 	agent	26 think
# 	agent	25 had
# 	agent	24 said
# 	agent	22 have
# 	agent	17 know
# 	agent	12 thought
# 	agent	9 give
# 	agent	8 do
# 	agent	8 saw
# 	agent	7 done
#
# 	patient	7 told
# 	patient	5 left
# 	patient	5 cried
# 	patient	4 tell
# 	patient	4 struck
# 	patient	4 persuaded
# 	patient	3 bring
# 	patient	3 find
# 	patient	3 led
# 	patient	3 advise
#
# 	mod	12 sure
# 	mod	8 girl
# 	mod	5 creature
# 	mod	3 daughter
# 	mod	3 safe
# 	mod	3 conscious
# 	mod	2 aware
# 	mod	2 ready
# 	mod	2 satisfied
# 	mod	2 insensible
#
# 92 1715 Mr. Knightley he/him/his
#
# 	poss	9 brother
# 	poss	7 opinion
# 	poss	7 Emma
# 	poss	5 head
# 	poss	4 father
# 	poss	4 life
# 	poss	4 answer
# 	poss	3 mind
# 	poss	3 thoughts
# 	poss	3 own
#
# 	agent	61 said
# 	agent	38 think
# 	agent	34 have
# 	agent	24 know
# 	agent	22 had
# 	agent	16 say
# 	agent	16 do
# 	agent	15 hope
# 	agent	14 saw
# 	agent	13 thought
#
# 	patient	9 see
# 	patient	5 thank
# 	patient	5 tell
# 	patient	3 excuse
# 	patient	3 consider
# 	patient	3 understand
# 	patient	3 found
# 	patient	3 have
# 	patient	3 call
# 	patient	3 suspect
#
# 	mod	10 sure
# 	mod	5 man
# 	mod	5 glad
# 	mod	4 afraid
# 	mod	3 sorry
# 	mod	3 silent
# 	mod	3 gentleman
# 	mod	2 happy
# 	mod	2 kind
# 	mod	2 judge
#
# 102 1137 Frank Churchill he/him/his
#
# 	poss	31 father
# 	poss	9 aunt
# 	poss	8 uncle
# 	poss	6 coming
# 	poss	6 spirits
# 	poss	5 hair
# 	poss	5 wife
# 	poss	4 time
# 	poss	4 feelings
# 	poss	3 favour
#
# 	agent	29 said
# 	agent	18 have
# 	agent	16 had
# 	agent	11 came
# 	agent	10 come
# 	agent	8 say
# 	agent	7 seemed
# 	agent	7 made
# 	agent	7 done
# 	agent	7 think
#
# 	patient	9 see
# 	patient	9 seeing
# 	patient	3 spare
# 	patient	3 gone
# 	patient	3 having
# 	patient	2 heard
# 	patient	2 persuade
# 	patient	2 like
# 	patient	2 persuaded
# 	patient	2 told
#
# 	mod	3 man
# 	mod	2 person
# 	mod	2 able
# 	mod	2 amiable
# 	mod	2 _
# 	mod	2 sure
# 	mod	2 cooler
# 	mod	2 sick
# 	mod	2 cross
# 	mod	2 comfortable
#
# 152 1065 Miss Fairfax she/her
#
# 	poss	12 aunt
# 	poss	8 grandmother
# 	poss	6 friends
# 	poss	6 situation
# 	poss	5 letter
# 	poss	4 health
# 	poss	4 complexion
# 	poss	4 voice
# 	poss	4 home
# 	poss	3 own
#
# 	agent	18 have
# 	agent	17 had
# 	agent	13 said
# 	agent	10 know
# 	agent	7 has
# 	agent	6 does
# 	agent	6 heard
# 	agent	5 says
# 	agent	4 think
# 	agent	4 get
#
# 	patient	5 bring
# 	patient	4 saw
# 	patient	4 see
# 	patient	3 have
# 	patient	3 had
# 	patient	3 like
# 	patient	3 hear
# 	patient	3 asked
# 	patient	3 known
# 	patient	3 ask
#
# 	mod	6 sure
# 	mod	2 unwell
# 	mod	2 elegant
# 	mod	2 better
# 	mod	2 sort
# 	mod	2 interested
# 	mod	2 woman
# 	mod	2 likely
# 	mod	2 ready
# 	mod	2 afraid
#
# 95 903 Mr. Elton he/him/his
#
# 	poss	6 wife
# 	poss	6 manners
# 	poss	5 being
# 	poss	5 friend
# 	poss	4 house
# 	poss	4 admiration
# 	poss	4 attachment
# 	poss	4 way
# 	poss	3 opinion
# 	poss	3 eyes
#
# 	agent	11 had
# 	agent	10 have
# 	agent	9 looked
# 	agent	7 said
# 	agent	7 know
# 	agent	6 going
# 	agent	6 came
# 	agent	5 do
# 	agent	4 seemed
# 	agent	4 saw
#
# 	patient	4 told
# 	patient	4 gone
# 	patient	3 seeing
# 	patient	3 saw
# 	patient	3 talked
# 	patient	3 seen
# 	patient	2 known
# 	patient	2 entreat
# 	patient	2 give
# 	patient	2 asked
#
# 	mod	7 man
# 	mod	3 sure
# 	mod	2 good
# 	mod	2 happy
# 	mod	2 sorry
# 	mod	1 sufferable
# 	mod	1 person
# 	mod	1 glad
# 	mod	1 useful
# 	mod	1 ready
#
# 207 731 Mrs. Elton she/her
#
# 	poss	6 friend
# 	poss	4 sister
# 	poss	4 friends
# 	poss	4 side
# 	poss	4 way
# 	poss	3 brother
# 	poss	3 resources
# 	poss	3 word
# 	poss	3 housekeeper
# 	poss	3 taste
#
# 	agent	18 have
# 	agent	15 assure
# 	agent	15 know
# 	agent	14 think
# 	agent	12 had
# 	agent	11 like
# 	agent	10 said
# 	agent	8 believe
# 	agent	8 do
# 	agent	6 take
#
# 	patient	10 assure
# 	patient	3 find
# 	patient	3 know
# 	patient	2 seen
# 	patient	2 convinced
# 	patient	2 ask
# 	patient	2 finding
# 	patient	2 reached
# 	patient	2 spoken
# 	patient	2 see
#
# 	mod	4 sure
# 	mod	3 afraid
# 	mod	2 woman
# 	mod	2 aware
# 	mod	2 fond
# 	mod	2 creature
# 	mod	2 obliging
# 	mod	1 excuse
# 	mod	1 ignorant
# 	mod	1 partial
#
# 88 729 Mrs. Weston she/her
#
# 	poss	9 Emma
# 	poss	5 husband
# 	poss	4 own
# 	poss	4 letters
# 	poss	3 Jane
# 	poss	2 marriage
# 	poss	2 touch
# 	poss	2 dearest
# 	poss	2 fears
# 	poss	2 opinion
#
# 	agent	23 said
# 	agent	19 had
# 	agent	16 think
# 	agent	10 know
# 	agent	8 do
# 	agent	8 have
# 	agent	8 say
# 	agent	6 suppose
# 	agent	6 heard
# 	agent	6 thought
#
# 	patient	3 told
# 	patient	3 obliged
# 	patient	2 gave
# 	patient	2 tell
# 	patient	2 seated
# 	patient	2 tells
# 	patient	2 see
# 	patient	2 understand
# 	patient	2 persuaded
# 	patient	2 indulge
#
# 	mod	6 sure
# 	mod	3 happy
# 	mod	3 disappointed
# 	mod	3 kind
# 	mod	2 convinced
# 	mod	2 ready
# 	mod	2 fond
# 	mod	2 sorry
# 	mod	2 glad
# 	mod	2 afraid
#
# 86 606 Mr. Weston he/him/his
#
# 	poss	20 son
# 	poss	10 wife
# 	poss	4 manners
# 	poss	4 word
# 	poss	3 approbation
# 	poss	2 daughter
# 	poss	2 friends
# 	poss	2 time
# 	poss	2 kindness
# 	poss	2 neighbours
#
# 	agent	18 said
# 	agent	9 know
# 	agent	7 have
# 	agent	7 told
# 	agent	6 thought
# 	agent	6 had
# 	agent	5 come
# 	agent	5 knew
# 	agent	5 gave
# 	agent	5 cried
#
# 	patient	5 see
# 	patient	4 assure
# 	patient	2 told
# 	patient	2 acquit
# 	patient	2 sunk
# 	patient	2 met
# 	patient	1 letting
# 	patient	1 plague
# 	patient	1 seen
# 	patient	1 forget
#
# 	mod	4 man
# 	mod	3 glad
# 	mod	2 happy
# 	mod	2 sure
# 	mod	1 native
# 	mod	1 favourite
# 	mod	1 confident
# 	mod	1 sanguine
# 	mod	1 chatty
# 	mod	1 convivial
#
# 105 559 Miss Bates she/her
#
# 	poss	12 niece
# 	poss	10 mother
# 	poss	3 will
# 	poss	3 voice
# 	poss	3 dear
# 	poss	2 youth
# 	poss	2 mind
# 	poss	2 grandmama
# 	poss	2 tippet
# 	poss	1 middle
#
# 	agent	16 said
# 	agent	7 had
# 	agent	7 know
# 	agent	7 have
# 	agent	5 see
# 	agent	5 think
# 	agent	5 go
# 	agent	5 came
# 	agent	4 do
# 	agent	3 replied
#
# 	patient	4 thank
# 	patient	2 forgotten
# 	patient	2 Thank
# 	patient	2 see
# 	patient	2 say
# 	patient	2 told
# 	patient	2 saw
# 	patient	2 obliged
# 	patient	2 questioned
# 	patient	1 hate
#
# 	mod	7 sure
# 	mod	3 woman
# 	mod	3 talker
# 	mod	2 kind
# 	mod	2 likely
# 	mod	2 obliging
# 	mod	2 tired
# 	mod	2 amusing
# 	mod	1 full
# 	mod	1 silly
#
# 85 526 Mr. Woodhouse he/him/his
#
# 	poss	21 daughter
# 	poss	15 dear
# 	poss	6 life
# 	poss	6 own
# 	poss	3 way
# 	poss	3 mind
# 	poss	3 friend
# 	poss	3 Isabella
# 	poss	3 Emma
# 	poss	2 family
#
# 	agent	13 said
# 	agent	10 had
# 	agent	7 made
# 	agent	6 saw
# 	agent	5 have
# 	agent	4 wish
# 	agent	4 say
# 	agent	4 dare
# 	agent	4 thought
# 	agent	4 think
#
# 	patient	2 see
# 	patient	2 keep
# 	patient	2 protected
# 	patient	1 animated
# 	patient	1 teased
# 	patient	1 visit
# 	patient	1 fancied
# 	patient	1 suited
# 	patient	1 constrain
# 	patient	1 restore
#
# 	mod	4 sorry
# 	mod	4 sure
# 	mod	3 afraid
# 	mod	2 able
# 	mod	2 ready
# 	mod	2 miserable
# 	mod	1 fanciful
# 	mod	1 troublesome
# 	mod	1 fond
# 	mod	1 interested
#
# 116 287 Mr. Martin he/him/his
#
# 	poss	2 mother
# 	poss	2 sisters
# 	poss	2 business
# 	poss	2 own
# 	poss	2 wife
# 	poss	2 appearance
# 	poss	2 manner
# 	poss	1 nature
# 	poss	1 being
# 	poss	1 shepherd
#
# 	agent	5 had
# 	agent	5 read
# 	agent	5 came
# 	agent	4 has
# 	agent	3 marry
# 	agent	3 reads
# 	agent	3 thought
# 	agent	3 said
# 	agent	3 asked
# 	agent	2 gone
#
# 	patient	4 marry
# 	patient	3 think
# 	patient	3 refuse
# 	patient	2 thought
# 	patient	2 know
# 	patient	2 refused
# 	patient	2 asked
# 	patient	2 accepted
# 	patient	1 sing
# 	patient	1 bid
#
# 	mod	4 man
# 	mod	2 obliging
# 	mod	2 sure
# 	mod	2 equal
# 	mod	1 clever
# 	mod	1 determined
# 	mod	1 sort
# 	mod	1 8th
# 	mod	1 old
# 	mod	1 rich
#
# 93 267 Miss Woodhouse she/her
#
# 	poss	2 opinion
# 	poss	1 you
# 	poss	1 news
# 	poss	1 spectacles
# 	poss	1 foot
# 	poss	1 inclination
# 	poss	1 approbation
# 	poss	1 hand
# 	poss	1 taste
# 	poss	1 remembrance
#
# 	agent	6 know
# 	agent	5 think
# 	agent	4 said
# 	agent	3 come
# 	agent	2 do
# 	agent	2 heard
# 	agent	2 saw
# 	agent	2 make
# 	agent	2 have
# 	agent	2 see
#
# 	patient	2 thought
# 	patient	1 brother!--Dear
# 	patient	1 give
# 	patient	1 hope
# 	patient	1 assure
# 	patient	1 reach
# 	patient	1 puzzle
# 	patient	1 meet
# 	patient	1 refresh
# 	patient	1 pity
#
# 	mod	2 right
# 	mod	2 afraid
# 	mod	1 obliging
# 	mod	1 good
# 	mod	1 satisfied
# 	mod	1 danger
# 	mod	1 person
# 	mod	1 presides
# 	mod	1 sure
# 	mod	1 thinking
#
# 84 241 Miss Woodhouse she/her
#
# 	poss	3 own
# 	poss	1 temper
# 	poss	1 judgment
# 	poss	1 loss
# 	poss	1 life
# 	poss	1 advantage
# 	poss	1 time
# 	poss	1 performances
# 	poss	1 friend
# 	poss	1 face
#
# 	agent	9 think
# 	agent	5 know
# 	agent	4 had
# 	agent	3 have
# 	agent	3 dare
# 	agent	3 looks
# 	agent	2 done
# 	agent	2 knows
# 	agent	2 feel
# 	agent	2 expect
#
# 	patient	2 miss
# 	patient	2 pity
# 	patient	2 see
# 	patient	1 say
# 	patient	1 used
# 	patient	1 lose
# 	patient	1 like
# 	patient	1 marry
# 	patient	1 saying
# 	patient	1 visit
#
# 	mod	3 sure
# 	mod	1 fond
# 	mod	1 gainer
# 	mod	1 sorry
# 	mod	1 glad
# 	mod	1 great
# 	mod	1 personage
# 	mod	1 near
# 	mod	1 ashamed
# 	mod	1 right
#
# 87 152 Isabella she/her
#
# 	poss	3 father
# 	poss	2 husband
# 	poss	2 ones
# 	poss	2 letters
# 	poss	2 throat
# 	poss	1 marriage
# 	poss	1 children
# 	poss	1 approbation
# 	poss	1 own
# 	poss	1 resolution
#
# 	agent	4 have
# 	agent	2 bear
# 	agent	2 venture
# 	agent	2 give
# 	agent	2 thought
# 	agent	1 finish
# 	agent	1 said
# 	agent	1 did
# 	agent	1 break
# 	agent	1 stirring
#
# 	patient	1 brings
# 	patient	1 applied
# 	patient	1 have
# 	patient	1 put
# 	patient	1 surprized
# 	patient	1 obliged
# 	patient	1 persuade
# 	patient	1 felt
# 	patient	1 asked
# 	patient	1 shewing
#
# 	mod	1 sorry
# 	mod	1 satisfied
# 	mod	1 wife
# 	mod	1 tired
# 	mod	1 sure
#
# 106 116 Mr. Perry he/him/his
#
# 	poss	3 carriage
# 	poss	2 opinion
# 	poss	1 surprize
# 	poss	1 directions
# 	poss	1 drugs
# 	poss	1 time
# 	poss	1 attention
# 	poss	1 horse
# 	poss	1 plan
# 	poss	1 friend
#
# 	agent	6 said
# 	agent	3 told
# 	agent	3 had
# 	agent	3 has
# 	agent	3 have
# 	agent	2 remonstrated
# 	agent	2 says
# 	agent	1 met
# 	agent	1 found
# 	agent	1 determined
#
# 	patient	2 seen
# 	patient	1 consulting
# 	patient	1 desired
# 	patient	1 wanted
# 	patient	1 ask
# 	patient	1 surprized
# 	patient	1 have
# 	patient	1 talked
# 	patient	1 asking
# 	patient	1 meet
#
# 	mod	1 sure
# 	mod	1 liberal
# 	mod	1 fond
# 	mod	1 sort
# 	mod	1 concerned
# 	mod	1 unknown
# 	mod	1 uneasy
#
# 98 115 Mrs. Churchill she/her
#
# 	poss	4 nephew
# 	poss	3 account
# 	poss	2 decease
# 	poss	2 husband
# 	poss	2 illness
# 	poss	1 temper
# 	poss	1 unwillingness
# 	poss	1 conservatory
# 	poss	1 head
# 	poss	1 injustice
#
# 	agent	2 have
# 	agent	2 has
# 	agent	2 lived
# 	agent	1 care
# 	agent	1 offered
# 	agent	1 rules
# 	agent	1 depends
# 	agent	1 mentioned
# 	agent	1 recovering
# 	agent	1 dared
#
# 	patient	1 knows
# 	patient	1 ordered
# 	patient	1 married
# 	patient	1 turned
# 	patient	1 recommended
# 	patient	1 carried
# 	patient	1 buried
# 	patient	1 spoken
# 	patient	1 admitted
# 	patient	1 acquitted
#
# 	mod	4 ill
# 	mod	2 unwell
# 	mod	1 winter
# 	mod	1 impatient
# 	mod	1 second
# 	mod	1 much
# 	mod	1 fond
# 	mod	1 tired
# 	mod	1 stationary
# 	mod	1 instigator
#
# 110 85 Mrs. Bates she/her
#
# 	poss	4 daughter
# 	poss	2 door
# 	poss	1 venturing
# 	poss	1 said--
# 	poss	1 house
# 	poss	1 employment
# 	poss	1 spectacles
# 	poss	1 Fairfax
# 	poss	1 powers
# 	poss	1 parlour
#
# 	agent	2 see
# 	agent	2 know
# 	agent	2 want
# 	agent	2 think
# 	agent	1 lived
# 	agent	1 considered
# 	agent	1 let
# 	agent	1 need
# 	agent	1 call
# 	agent	1 take
#
# 	patient	2 passed
# 	patient	1 hurt
# 	patient	1 help
# 	patient	1 say
# 	patient	1 wish
# 	patient	1 hope
# 	patient	1 engaged
# 	patient	1 saw
#
# 	mod	1 lady
# 	mod	1 deal
# 	mod	1 afraid
# 	mod	1 able
# 	mod	1 sure
#
# 164 82 Colonel Campbell he/him/his
#
# 	poss	4 daughter
# 	poss	3 return
# 	poss	2 power
# 	poss	2 spirits
# 	poss	1 life
# 	poss	1 wish
# 	poss	1 family
# 	poss	1 income
# 	poss	1 fortune
# 	poss	1 residence
#
# 	agent	2 think
# 	agent	2 wish
# 	agent	2 claimed
# 	agent	1 believed
# 	agent	1 learn
# 	agent	1 return
# 	agent	1 sought
# 	agent	1 took
# 	agent	1 hoped
# 	agent	1 employed
#
# 	patient	1 accompanying
# 	patient	1 loves
#
# 	mod	2 able
# 	mod	2 particular
# 	mod	2 man
# 	mod	1 deaf
# 	mod	1 person
# 	mod	1 giver
#
# 109 71 Mrs. Goddard she/her
#
# 	poss	2 school
# 	poss	2 day
# 	poss	2 door
# 	poss	1 room
# 	poss	1 hands
# 	poss	1 line
# 	poss	1 acquaintance
# 	poss	1 rest
# 	poss	1 morning
# 	poss	1 absences
#
# 	agent	1 say
# 	agent	1 chose
# 	agent	1 dressed
# 	agent	1 asked
# 	agent	1 knew
# 	agent	1 nursed
# 	agent	1 cares
# 	agent	1 loves
# 	agent	1 want
# 	agent	1 thank
#
# 	patient	2 see
# 	patient	1 invite
# 	patient	1 gone
#
# 	mod	1 mistress
# 	mod	1 school
# 	mod	1 near
# 	mod	1 able
# 	mod	1 artless
#
# 192 68 Mr. Dixon he/him/his
#
# 	poss	1 name
# 	poss	1 place
# 	poss	1 addresses
# 	poss	1 home
# 	poss	1 account
# 	poss	1 actions
# 	poss	1 wife
# 	poss	1 conversation
# 	poss	1 connexions
# 	poss	1 character
#
# 	agent	2 caught
# 	agent	1 like
# 	agent	1 paying
# 	agent	1 telling
# 	agent	1 shewn
# 	agent	1 had
# 	agent	1 feel
# 	agent	1 expected
# 	agent	1 see
# 	agent	1 hear
#
# 	patient	1 taken
# 	patient	1 reckoned
# 	patient	1 fancy
# 	patient	1 called
# 	patient	1 comprehend
#
# 	mod	2 man
# 	mod	2 plain
# 	mod	1 obliging
# 	mod	1 near
# 	mod	1 musical
# 	mod	1 persons
# 	mod	1 friend
# 	mod	1 principal
#
# 184 60 the Coles they/them/their
#
# 	poss	2 inclination
# 	poss	2 room
# 	poss	1 first
# 	poss	1 income
# 	poss	1 wealth
# 	poss	1 views
# 	poss	1 want
# 	poss	1 house
# 	poss	1 number
# 	poss	1 expenses
#
# 	agent	2 had
# 	agent	1 lived
# 	agent	1 brought
# 	agent	1 yielded
# 	agent	1 added
# 	agent	1 presume
# 	agent	1 did
# 	agent	1 arrange
# 	agent	1 receive
# 	agent	1 take
#
# 	patient	1 expressed
# 	patient	1 take
# 	patient	1 mortify
# 	patient	1 delighted
# 	patient	1 calls
#
# 	mod	2 people
# 	mod	1 respectable
#
# 185 54 Mrs. Cole she/her
#
# 	poss	1 kindness
# 	poss	1 honour
# 	poss	1 note
# 	poss	1 side
#
# 	agent	2 began
# 	agent	2 had
# 	agent	2 heard
# 	agent	2 said
# 	agent	1 came
# 	agent	1 know
# 	agent	1 say
# 	agent	1 went
# 	agent	1 sat
# 	agent	1 wrote
#
# 	patient	1 said
# 	patient	1 Thank
# 	patient	1 telling
# 	patient	1 told
# 	patient	1 give
# 	patient	1 hurting
# 	patient	1 borrow
# 	patient	1 seeing
#
# 	mod	2 kind
#
# 354 52 Harriet she/her
#
# 	poss	2 own
# 	poss	1 respectable
# 	poss	1 thoughts
# 	poss	1 claims
# 	poss	1 happiness
# 	poss	1 due
# 	poss	1 estimate
# 	poss	1 faults
#
# 	agent	2 doing
# 	agent	1 prevented
# 	agent	1 had
# 	agent	1 dare
# 	agent	1 seemed
# 	agent	1 taught
# 	agent	1 enjoyed
# 	agent	1 felt
# 	agent	1 known
# 	agent	1 deserved
#
# 	patient	2 told
# 	patient	1 brought
# 	patient	1 left
# 	patient	1 prevented
# 	patient	1 fancy
# 	patient	1 marrying
# 	patient	1 taught
# 	patient	1 elevate
# 	patient	1 threatened
# 	patient	1 loved
#
# 	mod	3 first
# 	mod	1 humble
# 	mod	1 insensible
# 	mod	1 dear
#
# 190 50 the Campbells they/them/their
#
# 	poss	2 daughter
# 	poss	1 country
# 	poss	1 way
# 	poss	1 motive
# 	poss	1 motives
# 	poss	1 sanction
# 	poss	1 selves
#
# 	agent	1 going
# 	agent	1 intended
# 	agent	1 coming
# 	agent	1 give
# 	agent	1 take
# 	agent	1 think
# 	agent	1 try
# 	agent	1 have
# 	agent	1 done
# 	agent	1 given
#
# 	patient	1 see
# 	patient	1 take
# 	patient	1 blame
# 	patient	1 guessed
# 	patient	1 join
# 	patient	1 wish
# 	patient	1 meet
#
#
# 145 44 Mr. Cole he/him/his
#
# 	poss	1 stables
# 	poss	1 door
# 	poss	1 horses
# 	poss	1 boy
# 	poss	1 's
# 	poss	1 neighbours
#
# 	agent	2 gave
# 	agent	1 heard
# 	agent	1 told
# 	agent	1 read
# 	agent	1 handed
# 	agent	1 touches
# 	agent	1 agreed
# 	agent	1 help
# 	agent	1 give
# 	agent	1 think
#
# 	patient	1 telling
# 	patient	1 indulging
# 	patient	1 followed
# 	patient	1 silenced
# 	patient	1 told
#
# 	mod	2 bilious
# 	mod	1 fond
# 	mod	1 mistaken
#
# 234 42 William Larkins he/him/his
#
# 	poss	6 master
# 	poss	1 kind
# 	poss	1 account
# 	poss	1 consent
# 	poss	1 wants
#
# 	agent	3 said
# 	agent	2 told
# 	agent	2 get
# 	agent	1 let
# 	agent	1 came
# 	agent	1 brought
# 	agent	1 had
# 	agent	1 seem
# 	agent	1 bid
# 	agent	1 mentioned
#
# 	patient	1 see
# 	patient	1 met
#
# 	mod	1 acquaintance
# 	mod	1 pleased
#
# 122 40 Mrs. John Knightley she/her
#
# 	poss	4 father
# 	poss	3 sister
# 	poss	2 children
# 	poss	1 family
# 	poss	1 health
# 	poss	1 Wingfield
# 	poss	1 acquaintance
#
# 	agent	1 respected
# 	agent	1 see
# 	agent	1 inherited
# 	agent	1 have
# 	agent	1 comprehend
# 	agent	1 think
# 	agent	1 done
# 	agent	1 had
# 	agent	1 pass
# 	agent	1 came
#
# 	patient	1 cried
#
# 	mod	2 woman
# 	mod	1 alarmed
# 	mod	1 delighted
# 	mod	1 eager
#
# 191 40 Mrs. Dixon she/her
#
# 	poss	4 father
# 	poss	2 mother
# 	poss	2 friend
# 	poss	1 performance
# 	poss	1 side
# 	poss	1 chusing
# 	poss	1 air
# 	poss	1 music
# 	poss	1 life
# 	poss	1 kind
#
# 	agent	1 persuaded
# 	agent	1 married
# 	agent	1 wrote
# 	agent	1 has
# 	agent	1 know
# 	agent	1 leading
# 	agent	1 falling
# 	agent	1 written
#
# 	patient	1 see
# 	patient	1 does
# 	patient	1 caught
# 	patient	1 mentioned
#
# 	mod	1 impatient
# 	mod	1 countries
# 	mod	1 disappointed
#
# 101 38 Randalls they/them/their
#
#
# 	agent	1 received
# 	agent	1 come
# 	agent	1 suppose
# 	agent	1 seem
# 	agent	1 makes
#
# 	patient	1 hear
# 	patient	1 found
# 	patient	1 like
# 	patient	1 reached
# 	patient	1 approaching
# 	patient	1 leaving
#
#
# 114 38 Mrs. Martin she/her
#
# 	poss	1 saying
# 	poss	1 friend
# 	poss	1 questions
# 	poss	1 's
#
# 	agent	1 having
# 	agent	1 came
# 	agent	1 taken
# 	agent	1 appeared
# 	agent	1 suspect
# 	agent	1 required
# 	agent	1 led
# 	agent	1 was
# 	agent	1 told
# 	agent	1 said
#
# 	patient	1 required
# 	patient	1 sink
# 	patient	1 visited
# 	patient	1 seen
# 	patient	1 believed
# 	patient	1 introducing
#
# 	mod	1 fond
# 	mod	1 care
# 	mod	1 kind
# 	mod	1 goose
#
# 125 34 Henry he/him/his
#
# 	poss	1 father
# 	poss	1 boys
# 	poss	1 kite
# 	poss	1 admiration
#
# 	agent	2 think
# 	agent	1 come
# 	agent	1 do
# 	agent	1 asked
# 	agent	1 appears
# 	agent	1 wishes
# 	agent	1 give
# 	agent	1 remain
# 	agent	1 replied
# 	agent	1 have
#
# 	patient	1 named
# 	patient	1 told
# 	patient	1 compare
# 	patient	1 take
#
# 	mod	1 boy
# 	mod	1 eldest
# 	mod	1 father
# 	mod	1 aware
#
# 117 33 Miss Nash she/her
#
# 	poss	1 sister
# 	poss	1 eyes
# 	poss	1 plans
# 	poss	1 proceedings
# 	poss	1 views
# 	poss	1 friend
# 	poss	1 range
# 	poss	1 work
# 	poss	1 comprehension
#
# 	agent	3 thinks
# 	agent	2 told
# 	agent	1 envy
# 	agent	1 seen
# 	agent	1 talked
# 	agent	1 said
# 	agent	1 knew
# 	agent	1 did
# 	agent	1 think
# 	agent	1 written
#
# 	patient	1 told
# 	patient	1 forgiven
#
# 	mod	1 sorry
#
# 186 32 Hetty she/her
#
# 	poss	1 eyes
# 	poss	1 room
# 	poss	1 letters
#
# 	agent	2 has
# 	agent	2 said
# 	agent	2 got
# 	agent	1 think
# 	agent	1 gone
# 	agent	1 lie
# 	agent	1 walking
# 	agent	1 written
# 	agent	1 says
# 	agent	1 go
#
# 	patient	2 excuse
# 	patient	1 put
# 	patient	1 make
# 	patient	1 gone
# 	patient	1 see
#
# 	mod	1 fortunate
# 	mod	1 low
# 	mod	1 delighted
# 	mod	1 happy
# 	mod	1 able
# 	mod	1 well
# 	mod	1 sorry
#
# 113 29 the Martins they/them/their
#
# 	poss	1 garden
#
# 	agent	2 having
# 	agent	1 occupied
# 	agent	1 heard
# 	agent	1 turned
# 	agent	1 miss
# 	agent	1 see
# 	agent	1 going
# 	agent	1 enjoy
# 	agent	1 wish
#
# 	patient	1 give
# 	patient	1 put
# 	patient	1 had
# 	patient	1 gone
# 	patient	1 miss
#
# 	mod	1 drink
# 	mod	1 deserving
#
# 292 29 Mrs. Weston.--“Very she/her
#
# 	poss	5 mother
# 	poss	3 word
# 	poss	1 Jane
#
# 	agent	4 thank
# 	agent	1 met
# 	agent	1 hope
# 	agent	1 said
# 	agent	1 made
# 	agent	1 forget
# 	agent	1 tell
# 	agent	1 know
# 	agent	1 think
# 	agent	1 protest!--and
#
#
# 	mod	1 sure
#
# 334 25 Mr. Knightley.--It he/him/his
#
# 	poss	2 mind
# 	poss	1 eyes
# 	poss	1 part.--He
# 	poss	1 lips
# 	poss	1 manners
# 	poss	1 disappearance
# 	poss	1 visit
# 	poss	1 countenance
# 	poss	1 unfinished
# 	poss	1 opinion.--He
#
# 	agent	2 change
# 	agent	2 seemed
# 	agent	1 looked
# 	agent	1 took
# 	agent	1 pressed
# 	agent	1 let
# 	agent	1 feel
# 	agent	1 had
# 	agent	1 moved
# 	agent	1 going
#
# 	patient	1 disturbing
#
#
# 104 23 Mrs. Perry she/her
#
# 	poss	1 dream
#
# 	agent	1 drank
# 	agent	1 tells
# 	agent	1 walking
# 	agent	1 told
# 	agent	1 setting
# 	agent	1 mentioned
# 	agent	1 had
# 	agent	1 telling
# 	agent	1 said
# 	agent	1 recommended
#
# 	patient	1 owing
#
# 	mod	1 anxious
# 	mod	1 fond
#
# 197 23 Miss Hawkins she/her
#
# 	poss	2 name
# 	poss	1 merits
# 	poss	1 home
# 	poss	1 happiness
# 	poss	1 conceit
# 	poss	1 set
#
# 	agent	1 played
# 	agent	1 wanted
# 	agent	1 thought
#
# 	patient	1 used
# 	patient	1 supposed
# 	patient	1 conceived
#
# 	mod	1 youngest
#
# 255 22 Mr. E. he/him/his
#
# 	poss	1 fears
#
# 	agent	2 speaking
# 	agent	2 know
# 	agent	1 expressing
# 	agent	1 come
#
# 	patient	3 assure
# 	patient	1 tell
# 	patient	1 Pass
# 	patient	1 expect
#
# 	mod	1 hand
#
# 90 20 James she/her
#
#
# 	agent	1 like
# 	agent	1 think
# 	agent	1 slighted
# 	agent	1 goes
# 	agent	1 come
# 	agent	1 see
# 	agent	1 seemed
# 	agent	1 know
# 	agent	1 take
# 	agent	1 put
#
# 	patient	1 talked
# 	patient	1 said
# 	patient	1 gone
#
# 	mod	1 obliged
#
# 120 19 Elizabeth she/her
#
# 	poss	1 buyings
# 	poss	1 calling
# 	poss	1 visit
#
# 	agent	2 saw
# 	agent	1 brother!--Dear
# 	agent	1 did
# 	agent	1 looked
# 	agent	1 took
# 	agent	1 went
# 	agent	1 came
# 	agent	1 do
# 	agent	1 used
# 	agent	1 seemed
#
# 	patient	1 lent
# 	patient	1 persuading
# 	patient	1 altered
#
#
# 151 19 the Mr. Knightleys he/him/his
#
# 	poss	2 dear
# 	poss	1 spending
# 	poss	1 had
# 	poss	1 ones
# 	poss	1 sir
#
# 	agent	2 have
# 	agent	1 proceeded
# 	agent	1 had
# 	agent	1 told
# 	agent	1 hope
#
# 	patient	1 killed
#
# 	mod	1 unpersuadable
# 	mod	1 sure
#
# 159 19 Mr. Wingfield he/him/his
#
# 	poss	1 brother
# 	poss	1 family
#
# 	agent	2 recommended
# 	agent	2 told
# 	agent	2 known
# 	agent	2 says
# 	agent	1 gone
# 	agent	1 considers
# 	agent	1 thinks
# 	agent	1 believe
# 	agent	1 had
# 	agent	1 understands
#
# 	patient	1 seen
# 	patient	1 depended
#
#
# 7 17 Enscombe he/him/his
#
# 	poss	1 wish
#
# 	agent	1 satisfy
# 	agent	1 please
# 	agent	1 dance
# 	agent	1 seemed
#
# 	patient	1 judged
# 	patient	1 concerned
# 	patient	1 dance
# 	patient	1 consulted
# 	patient	1 interest
#
# 	mod	1 gracious
# 	mod	1 cold
#
# 143 17 the Eltons he/him/his
#
# 	poss	1 departure
#
# 	agent	1 brought
# 	agent	1 talking
# 	agent	1 made
# 	agent	1 walked
#
# 	patient	1 acquainted
# 	patient	1 respecting
#
#
# 91 16 Hannah she/her
#
#
# 	agent	1 make
# 	agent	1 turns
# 	agent	1 bangs
# 	agent	1 hearing
#
# 	patient	1 got
# 	patient	1 mentioned
# 	patient	1 see
# 	patient	1 had
# 	patient	1 used
# 	patient	1 tell
#
# 	mod	1 girl
# 	mod	1 servant
#
# 100 16 the Churchills he/him/his
#
#
# 	agent	2 have
# 	agent	1 allow
# 	agent	1 removed
#
# 	patient	1 leave
#
# 	mod	1 likely
#
# 193 16 Miss Campbell she/her
#
# 	poss	1 friend
#
# 	agent	1 married
# 	agent	1 allow
# 	agent	1 appear
#
# 	patient	1 telling
# 	patient	1 gone
#
# 	mod	1 plain
# 	mod	1 elegant
# 	mod	1 persons
#
# 24 16 Donwell she/her
#
#
# 	agent	1 received
# 	agent	1 come
# 	agent	1 suppose
# 	agent	1 lose
#
# 	patient	1 have
# 	patient	1 consider
#
#
# 252 16 Selina she/her
#
# 	poss	1 nicety
# 	poss	1 sheets
#
# 	agent	1 said
# 	agent	1 going
# 	agent	1 given
# 	agent	1 played
# 	agent	1 feels
# 	agent	1 says
# 	agent	1 believe
# 	agent	1 travels
# 	agent	1 enjoy
#
#
# 	mod	1 lady
# 	mod	1 rule
#
# 196 14 Patty she/her
#
#
# 	agent	1 washing
# 	agent	1 came
# 	agent	1 thought
# 	agent	1 come
# 	agent	1 makes
# 	agent	1 told
# 	agent	1 shocked
# 	agent	1 opened
# 	agent	1 has
# 	agent	1 announcing
#
# 	patient	1 told
# 	patient	1 bid
#
#
# 251 13 Mr. Suckling he/him/his
#
# 	poss	1 comparison
# 	poss	1 death
#
# 	agent	1 went
# 	agent	1 believe
# 	agent	1 completed
# 	agent	1 had
# 	agent	1 used
#
# 	patient	1 taken
# 	patient	1 say
#
# 	mod	1 fond
# 	mod	1 friend
#
# 141 11 Miss Woodhouse she/her
#
# 	poss	1 book
#
# 	agent	1 do
# 	agent	1 write
# 	agent	1 know
# 	agent	1 divide
# 	agent	1 object
#
#
# 	mod	1 eyes
#
# 96 10 Captain Weston he/him/his
#
# 	poss	1 life
# 	poss	1 wife
#
#
# 	patient	1 introduced
# 	patient	1 seen
# 	patient	1 relieved
#
# 	mod	1 favourite
#
# 144 10 Shakespeare he/him/his
#
# 	poss	1 book
#
# 	agent	1 thought
# 	agent	1 read
# 	agent	1 consider
# 	agent	1 found
# 	agent	1 write
# 	agent	1 got
#
#
# 	mod	1 able
# 	mod	1 sure
#
# 4172 9 Mrs. Ford.--“Yes they/them/their
#
# 	poss	1 pattern
#
# 	agent	2 take
# 	agent	1 asked
# 	agent	1 want
# 	agent	1 have
# 	agent	1 know
# 	agent	1 sent
#
#
#
# 330 9 Mrs. Smallridge she/her
#
# 	poss	1 girls
# 	poss	1 situation
# 	poss	1 children
#
#
#
# 	mod	1 intimate
# 	mod	1 children
#
# 332 9 old John Abdy he/him/his
#
# 	poss	2 son
# 	poss	1 joints
#
# 	agent	1 have
#
# 	patient	1 see
#
# 	mod	1 clerk
#
# 61 9 Richmond he/him/his
#
# 	poss	2 dear
#
# 	agent	2 hope
# 	agent	1 dare
#
#
# 	mod	1 glad
# 	mod	1 sure
#
# 97 8 Miss Churchill she/her
#
# 	poss	1 brother
# 	poss	1 wife
# 	poss	1 fortune
#
# 	agent	1 fell
#
# 	patient	1 threw
#
#
# 3 8 Highbury she/her
#
# 	poss	1 wan
#
# 	agent	1 feel
# 	agent	1 promised
# 	agent	1 known
#
# 	patient	1 made
# 	patient	1 finding
#
#
# 108 8 the Westons he/him/his
#
#
# 	agent	1 arrived
# 	agent	1 think
#
# 	patient	1 brought
# 	patient	1 married
#
#
# 132 8 Mr. Knightley he/him/his
#
# 	poss	1 life
#
# 	agent	2 quarrel
# 	agent	1 had
#
# 	patient	1 convince
# 	patient	1 obliged
# 	patient	1 own
#
#
# 233 8 Mrs. Wallis she/her
#
# 	poss	1 boy
#
# 	agent	2 eats
# 	agent	1 sent
# 	agent	1 makes
# 	agent	1 gets
# 	agent	1 likes
# 	agent	1 does
#
#
# 	mod	1 uncivil
#
# 235 8 Mrs. Hodges she/her
#
# 	poss	1 master
#
# 	agent	1 bear
#
# 	patient	1 holds
#
# 	mod	1 displeased
# 	mod	1 angry
#
# 277 8 Mrs. Bragge she/her
#
# 	poss	1 family
#
# 	agent	1 moves
#
#
# 	mod	1 one
#
# 126 7 George he/him/his
#
#
#
# 	patient	1 saw
# 	patient	1 calling
#
#
# 149 7 Grandpapa he/him/his
#
#
# 	agent	1 give
# 	agent	1 compare
# 	agent	1 think
#
#
# 	mod	1 gentle
#
# 161 7 the Bateses they/them/their
#
#
# 	agent	1 lodged
#
#
#
# 225 7 Anne Cox she/her
#
#
# 	agent	2 meant
# 	agent	1 asked
# 	agent	1 said
#
#
#
# 242 7 Mrs. Stokes she/her
#
# 	poss	1 room
#
# 	agent	1 know
# 	agent	1 standing
# 	agent	1 said
# 	agent	1 had
#
# 	patient	1 know
# 	patient	1 saw
#
#
# 1986 7 Mr. they/them/their
#
#
# 	agent	1 forgetting
# 	agent	1 seen
# 	agent	1 have
# 	agent	1 appeared
# 	agent	1 passed
#
# 	patient	1 acquainted
# 	patient	1 put
#
#
# 4923 7 Mr. he/him/his
#
# 	poss	1 finger
#
# 	agent	1 came
# 	agent	1 cutting
# 	agent	1 cut
# 	agent	1 kept
#
# 	patient	1 supply
#
#
# 351 7 Mr. Knightley.--Every he/him/his
#
# 	poss	1 expense
# 	poss	1 brother
#
# 	agent	1 known
#
# 	patient	1 sink
#
#
# 893 6 Mr. he/him/his
#
# 	poss	1 horses
# 	poss	1 coachman
# 	poss	1 alarms
# 	poss	1 nerves
#
# 	agent	1 thought
#
#
#
# 157 6 Henry he/him/his
#
# 	poss	1 account
#
# 	agent	1 have
# 	agent	1 supplanted.--Mr
#
# 	patient	1 giving
# 	patient	1 have
# 	patient	1 injure
#
#
# 3817 6 Mr. Woodhouse--“indeed they/them/their
#
# 	poss	1 sir
# 	poss	1 mother
# 	agent	1 forget
# 	agent	1 imagine
#
#
# 	mod	1 sure
#
# 204 6 Augusta she/her
#
# 	poss	1 will
#
# 	agent	1 stir
# 	agent	1 said
#
#
#
# 212 6 Mrs. Ford she/her
#
#
# 	agent	1 said
#
# 	patient	1 approaching
#
#
# 216 6 Mr. Cox he/him/his
#
# 	poss	1 family
#
# 	agent	1 letting
#
# 	patient	1 letting
# 	patient	1 ask
#
#
# 229 6 Voices they/them/their
#
#
# 	agent	1 approached
# 	agent	1 hope
# 	agent	1 beg
# 	agent	1 see
# 	agent	1 hear
#
# 	patient	1 met
#
#
# 313 6 the Sucklings they/them/their
#
# 	poss	1 landau
#
# 	agent	1 come
#
#
#
# 2570 6 Mrs. she/her
#
# 	poss	1 cure
#
#
# 	patient	1 appeased
# 	patient	1 restored
# 	patient	1 seen
#
#
# 133 5 Kitty she/her
#
#
# 	agent	1 Kindled
# 	agent	1 recollect
#
#
#
# 154 5 Papa he/him/his
#
# 	poss	1 regret
#
# 	agent	2 think
# 	agent	1 speaking
# 	agent	1 giving
#
#
#
# 163 5 Mrs. John Knightley.--“It she/her
#
#
# 	agent	1 seen
# 	agent	1 suppose
#
#
# 	mod	1 happy
#
# 4072 5 Mr. he/him/his
#
# 	poss	1 proposals
#
# 	agent	2 became
# 	agent	1 had
#
#
#
# 244 5 Frank.--Go she/her
#
# 	poss	1 pardon
#
# 	agent	1 bring
# 	agent	1 wish
#
#
#
# 295 5 Miss Woodhouse she/her
#
#
# 	agent	1 followed
# 	agent	1 Come
# 	agent	1 set
#
#
#
# 308 5 Miss Bickerton she/her
#
# 	poss	1 way
#
# 	agent	1 gave
# 	agent	1 calling
# 	agent	1 ran
#
# 	patient	1 follow
#
#
# 107 4 the little Perrys they/them/their
#
# 	poss	1 hands
#
#
#
#
# 139 4 Neptune he/him/his
#
#
# 	agent	1 brought
# 	agent	1 bringing
#
#
#
# 195 4 the Dixons she/her
#
#
# 	agent	1 deny
#
#
#
# 4297 4 Mr. he/him/his
#
# 	poss	1 life
#
# 	agent	1 do
# 	agent	1 thought
#
#
#
# 253 4 Mrs. Partridge she/her
#
#
#
#
#
# 266 4 Wright he/him/his
#
#
# 	agent	1 done
# 	agent	1 holds
#
# 	patient	1 promised
#
#
# 268 4 Poor Jane Fairfax!”--thought he/him/his
#
#
# 	agent	1 deserved
# 	agent	1 done
#
#
#
# 276 4 June she/her
#
#
#
#
#
# 287 4 Uncle Knightley he/him/his
#
# 	poss	1 accounts
#
#
#
#
# 315 4 Cowper he/him/his
#
# 	poss	1 fire
#
# 	agent	1 creating
# 	agent	1 saw
#
#
#
# 316 4 Mrs. Suckling she/her
#
# 	poss	1 family
#
#
#
#
# 370 4 Mrs. S. she/her
#
#
# 	agent	1 admits
# 	agent	1 writes
#
#
# 	mod	1 creature
#
# 386 4 Anna Weston she/her
#
#
#
#
#
# 112 3 Serle he/him/his
#
#
# 	agent	1 understands
# 	agent	1 see
#
#
#
# 187 3 Good God he/him/his
#
#
#
# 	patient	1 thank
#
#
# 224 3 The Coxes they/them/their
#
#
# 	agent	1 wondering
# 	agent	1 looked
# 	agent	1 do
#
#
#
# 240 3 Miss _ Gilbert she/her
#
# 	poss	1 brother
#
#
# 	patient	1 asked
#
#
# 51 3 Maple Grove she/her
#
#
# 	agent	2 given
#
#
#
# 298 3 Mr. Richard?--Oh he/him/his
#
#
#
# 	patient	1 disturb
#
#
# 319 3 Emma.--She she/her
#
#
# 	agent	1 speak
#
#
#
# 3319 2 Mr. he/him/his
#
#
# 	agent	1 prevent
#
#
# 	mod	1 man
#
# 155 2 Mr. Woodhouse--“yes he/him/his
#
#
# 	agent	1 said
#
#
#
# 156 2 Weston Churchill he/him/his
#
#
#
# 	patient	1 signed
#
#
# 162 2 Mr. Graham he/him/his
#
# 	poss	1 intending
# 	poss	1 estate
#
#
#
#
# 173 2 Good Heaven he/him/his
#
#
#
#
#
# 181 2 her;--William Coxe -- Oh she/her
#
#
#
# 	patient	1 endure
#
#
# 183 2 Mrs. Churchill--'Every she/her
#
#
#
#
#
# 231 2 Mr. Woodhouse?--I he/him/his
#
#
#
#
# 	mod	1 glad
# 	mod	1 glad.--Quite
#
# 241 2 Emma!--Emma she/her
#
#
# 	agent	1 catch
#
#
#
# 249 2 Dear Harriet!--I he/him/his
#
#
# 	agent	1 change
#
# 	patient	1 change
#
#
# 254 2 Mrs. Elton's she/her
#
#
#
#
#
# 265 2 Jane Fairfax.--A she/her
#
#
#
#
#
# 282 2 Mr. Frank Churchill.--At he/him/his
#
# 	poss	1 mother
#
#
#
#
# 284 2 Tea he/him/his
#
#
# 	agent	1 carrying
# 	agent	1 passed
# 	agent	1 seemed
#
#
#
# 296 2 Dr. Hughes he/him/his
#
#
#
#
#
# 297 2 Mrs. Hughes she/her
#
#
#
#
#
# 300 2 Miss Otway she/her
#
#
#
# 	patient	1 saw
#
#
# 5023 2 Mr. he/him/his
#
#
#
#
#
# 328 2 Harriet.--It they/them/their
#
#
# 	agent	1 seem
#
# 	patient	1 seeing
#
#
# 331 2 Bragges he/him/his
#
#
#
#
#
# 339 2 the Mrs. Eltons she/her
#
#
#
#
#
# 364 2 Miss W. she/her
#
#
#
#
#
# 396 2 Astley they/them/their
